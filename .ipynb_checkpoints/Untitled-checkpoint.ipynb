# %%
import pandas as pd

# %%
lista = [1,2,3,4]
lista = pd.Series(lista)
lista

# %%
df_lojas = pd.read_excel('Vendas.xlsx')
df_lojas
# Out:
#          Data                     ID Loja  Produto  Quantidade  \
# 0  2019-12-01           Iguatemi Campinas    Calça           2
# 1  2019-12-03           Iguatemi Campinas   Camisa           3
# 2  2019-12-04          Iguatemi Esplanada  Bermuda           1
# 3  2019-12-04           Iguatemi Campinas  Bermuda           4
# 4  2019-12-05  Center Shopping Uberlândia  Chinelo           1
# 5  2019-12-05           Iguatemi Campinas    Gorro           2
# 6  2019-12-05           Iguatemi Campinas  Bermuda           4
# 7  2019-12-05         Bourbon Shopping SP    Gorro           3
# 8  2019-12-06           Iguatemi Campinas    Cinto           2
# 9  2019-12-06         Bourbon Shopping SP  Chinelo           1
# 10 2019-12-07         Bourbon Shopping SP  Bermuda           3
# 11 2019-12-07           Iguatemi Campinas    Gorro           1
# 12 2019-12-07          Iguatemi Esplanada   Camisa           1
# 13 2019-12-08  Center Shopping Uberlândia    Calça           5
# ...

# %%
df_nba = pd.read_csv('Players.csv')
df_nba
# Out:
#       Unnamed: 0             Player  height  weight  \
# 0              0    Curly Armstrong   180.0    77.0
# 1              1       Cliff Barker   188.0    83.0
# 2              2      Leo Barnhorst   193.0    86.0
# 3              3         Ed Bartels   196.0    88.0
# 4              4        Ralph Beard   178.0    79.0
# ...          ...                ...     ...     ...
# 3917        3917      Troy Williams   198.0    97.0
# 3918        3918       Kyle Wiltjer   208.0   108.0
# 3919        3919  Stephen Zimmerman   213.0   108.0
# 3920        3920        Paul Zipser   203.0    97.0
# 3921        3921        Ivica Zubac   216.0   120.0
#
#                               collage    born      birth_city  \
# 0                  Indiana University  1918.0             NaN
# 1              University of Kentucky  1921.0        Yorktown
# 2            University of Notre Dame  1924.0             NaN
# 3     North Carolina State University  1925.0             NaN
# ...

# %%
print(df_nba.shape) # numero de linhas e colunas

print(df_nba.size) # número de dados

print(df_nba.dtypes) # colunas e seus tipos

print(df_nba.columns) # colunas em uma lista

print(df_nba.index) # número de linhas

print(df_nba.values) # arrays de cada linha separados com espaço
# Out:
# (3922, 8)
# 31376
# Unnamed: 0       int64
# Player          object
# height         float64
# weight         float64
# collage         object
# born           float64
# birth_city      object
# birth_state     object
# dtype: object
# Index(['Unnamed: 0', 'Player', 'height', 'weight', 'collage', 'born',
#        'birth_city', 'birth_state'],
#       dtype='object')
# RangeIndex(start=0, stop=3922, step=1)
# [[0 'Curly Armstrong' 180.0 ... 1918.0 nan nan]
#  [1 'Cliff Barker' 188.0 ... 1921.0 'Yorktown' 'Indiana']
#  [2 'Leo Barnhorst' 193.0 ... 1924.0 nan nan]
#  ...
#  [3919 'Stephen Zimmerman' 213.0 ... 1996.0 'Hendersonville' 'Tennessee']
#  [3920 'Paul Zipser' 203.0 ... 1994.0 'Heidelberg' 'Germany']
#  [3921 'Ivica Zubac' 216.0 ... 1997.0 'Mostar' 'Bosnia and Herzegovina']]

# %%
df_nba.head(10) # As primeiras linhas do dataframe
# Out:
#    Unnamed: 0           Player  height  weight  \
# 0           0  Curly Armstrong   180.0    77.0
# 1           1     Cliff Barker   188.0    83.0
# 2           2    Leo Barnhorst   193.0    86.0
# 3           3       Ed Bartels   196.0    88.0
# 4           4      Ralph Beard   178.0    79.0
# 5           5       Gene Berce   180.0    79.0
# 6           6    Charlie Black   196.0    90.0
# 7           7      Nelson Bobb   183.0    77.0
# 8           8  Jake Bornheimer   196.0    90.0
# 9           9     Vince Boryla   196.0    95.0
#
#                            collage    born     birth_city   birth_state
# 0               Indiana University  1918.0            NaN           NaN
# 1           University of Kentucky  1921.0       Yorktown       Indiana
# 2         University of Notre Dame  1924.0            NaN           NaN
# 3  North Carolina State University  1925.0            NaN           NaN
# 4           University of Kentucky  1927.0    Hardinsburg      Kentucky
# ...

# %%
df_nba.tail(10) # As últimas linhas do dataframe
# Out:
#       Unnamed: 0                 Player  height  weight  \
# 3912        3912       Denzel Valentine   198.0    96.0
# 3913        3913          Fred VanVleet   183.0    88.0
# 3914        3914  Taurean Waller-Prince   183.0    88.0
# 3915        3915            Okaro White   203.0    92.0
# 3916        3916       Isaiah Whitehead   193.0    96.0
# 3917        3917          Troy Williams   198.0    97.0
# 3918        3918           Kyle Wiltjer   208.0   108.0
# 3919        3919      Stephen Zimmerman   213.0   108.0
# 3920        3920            Paul Zipser   203.0    97.0
# 3921        3921            Ivica Zubac   216.0   120.0
#
#                               collage    born      birth_city  \
# 3912        Michigan State University  1993.0         Lansing
# 3913         Wichita State University  1994.0        Rockford
# 3914                              NaN  1994.0             NaN
# 3915         Florida State University  1992.0      Clearwater
# ...

# %%
df_nba.head(20).to_csv(r'C:\Users\Londres27\Desktop\Andriel\new.csv') # criar um arquivo csv

# %%
print(df_nba['height'].min()) # menor valor de uma coluna
print(df_nba['height'].max()) # maior valor de uma coluna
print(df_nba['height'].mean()) # média de uma coluna
# Out:
# 160.0
# 231.0
# 198.70492221372098

# %%
df_sort = df_nba.sort_values(by='height')
df_sort
# Out:
#       Unnamed: 0            Player  height  weight  \
# 1837        1837     Muggsy Bogues   160.0    61.0
# 2587        2587      Earl Boykins   165.0    61.0
# 1764        1764         Spud Webb   168.0    60.0
# 2207        2207    Keith Jennings   170.0    72.0
# 1215        1215        Monte Towe   170.0    68.0
# ...          ...               ...     ...     ...
# 2249        2249        P.J. Brown   229.0   106.0
# 2248        2248     Shawn Bradley   229.0   106.0
# 1711        1711        Manute Bol   231.0    90.0
# 2297        2297  Gheorghe Muresan   231.0   137.0
# 223          223               NaN     NaN     NaN
#
#                               collage    born birth_city  birth_state
# 1837           Wake Forest University  1965.0  Baltimore     Maryland
# 2587      Eastern Michigan University  1976.0  Cleveland         Ohio
# 1764  North Carolina State University  1963.0     Dallas        Texas
# ...

# %% [markdown]
# ## Média de altura

# %%
media_altura = df_nba['height'].mean()
print(media_altura)
# Out:
# 198.70492221372098

# %% [markdown]
# ## Média de peso

# %%
media_peso = df_nba['weight'].mean()
print(media_peso)
# Out:
# 94.78321856669217

# %% [markdown]
# ## Maior altura

# %%
altura_max = df_nba['height'].max()
print(altura_max)
# Out:
# 231.0

# %% [markdown]
# ## Maior peso

# %%
peso_max = df_nba['weight'].max()
print(peso_max)
# Out:
# 163.0

# %% [markdown]
# ## Menor altura

# %%
altura_min = df_nba['height'].min()
print(altura_min)
# Out:
# 160.0

# %% [markdown]
# ## Menor peso

# %%
peso_min = df_nba['weight'].min()
print(peso_min)
# Out:
# 60.0

# %% [markdown]
# ## Estado onde nasce o maior número de jogadores

# %%
state_max_players = df_nba['birth_state'].value_counts().head(1)
print(state_max_players)
# Out:
# California    344
# Name: birth_state, dtype: int64

# %% [markdown]
# ## Jogador mais alto

# %%
highest_player = df_nba.sort_values(by='height').head(1)
print(highest_player)
# Out:
#       Unnamed: 0         Player  height  weight                 collage  \
# 1837        1837  Muggsy Bogues   160.0    61.0  Wake Forest University
#
#         born birth_city birth_state
# 1837  1965.0  Baltimore    Maryland

# %% [markdown]
# ## Nova coluna com a razão peso/altura

# %%
df_nba['division'] = df_nba['weight'] / df_nba['height']
df_nba
# Out:
#       Unnamed: 0             Player  height  weight  \
# 0              0    Curly Armstrong   180.0    77.0
# 1              1       Cliff Barker   188.0    83.0
# 2              2      Leo Barnhorst   193.0    86.0
# 3              3         Ed Bartels   196.0    88.0
# 4              4        Ralph Beard   178.0    79.0
# ...          ...                ...     ...     ...
# 3917        3917      Troy Williams   198.0    97.0
# 3918        3918       Kyle Wiltjer   208.0   108.0
# 3919        3919  Stephen Zimmerman   213.0   108.0
# 3920        3920        Paul Zipser   203.0    97.0
# 3921        3921        Ivica Zubac   216.0   120.0
#
#                               collage    born      birth_city  \
# 0                  Indiana University  1918.0             NaN
# 1              University of Kentucky  1921.0        Yorktown
# 2            University of Notre Dame  1924.0             NaN
# 3     North Carolina State University  1925.0             NaN
# ...

# %%
df_nba.sort_values(by='division').tail(5)
# Out:
#       Unnamed: 0             Player  height  weight  \
# 3432        3432     Nikola Pekovic   211.0   139.0
# 2222        2222  Shaquille O'Neal*   216.0   147.0
# 2403        2403    Thomas Hamilton   218.0   149.0
# 3686        3686        Sim Bhullar   226.0   163.0
# 223          223                NaN     NaN     NaN
#
#                           collage    born    birth_city birth_state  division
# 3432                          NaN  1986.0  Bijelo Polje  Montenegro  0.658768
# 2222   Louisiana State University  1972.0        Newark  New Jersey  0.680556
# 2403     University of Pittsburgh  1975.0       Chicago    Illinois  0.683486
# 3686  New Mexico State University  1992.0       Ontario      Canada  0.721239
# 223                           NaN     NaN           NaN         NaN       NaN
